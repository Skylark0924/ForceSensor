# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
data_none=pd.read_csv("data_空载.txt")

# %%
data_none.plot()
plt.show()
data_none.shape
# Out:
# (19999, 7)

# %%
label1=[[0] * 6] * 20000
for i in range(0,2000):
    label1[i]=[0,0,0,0,0,0]
    label1[i+2000]=[0,0,-100,0,0,0]
    label1[i+4000]=[0,0,-200,0,0,0]
    label1[i+6000]=[0,0,-300,0,0,0]
    label1[i+8000]=[0,0,-400,0,0,0]
    label1[i+10000]=[0,0,-500,0,0,0]
    label1[i+12000]=[0,0,-600,0,0,0]
    label1[i+14000]=[0,0,-800,0,0,0]
    label1[i+16000]=[0,0,-1000,0,0,0]
    label1[i+18000]=[0,0,0,0,0,0]
label1=pd.DataFrame(label1)

# %%
data_z1=pd.read_csv("data_z+向上_中心受力.txt")
data_z1.plot()
plt.show()
data_z1.shape
# Out:
# (19999, 7)

# %%
data_z2=pd.read_csv("data_z+向上_x+外.txt") ##舍弃
data_z2.plot()
plt.show()
data_z2.shape
# Out:
# (7999, 7)

# %%
data_z3=pd.read_csv("data_z+向上_x-外.txt")
data_z3.plot()
plt.show()
data_z3.shape
# Out:
# (19999, 7)

# %%
data_z4=pd.read_csv("data_z+向上_y正外孔受力.txt")
data_z4.plot()
plt.show()
data_z4.shape
# Out:
# (19999, 7)

# %%
data_z5=pd.read_csv("data_z+向上_y-外.txt")
data_z5.plot()
plt.show()
data_z5.shape
# Out:
# (17999, 7)

# %%
data_z6=pd.read_csv("data_z+向上_y+到x+30度.txt")
data_z6.plot()
plt.show()
data_z6.shape
# Out:
# (13999, 7)

# %%
data_z7=pd.read_csv("data_z+向上_y+到x+60度.txt")
data_z7.plot()
plt.show()
data_z7.shape
# Out:
# (19999, 7)

# %%
data_x1=pd.read_csv("data_x+向上_y+外.txt")
data_x1.plot()
plt.show()
data_x1.shape
# Out:
# (19999, 7)

# %%
data_x1=pd.read_csv("data_x+向上_y-外.txt")
data_x1.plot()
plt.show()
data_x1.shape
# Out:
# (19999, 7)

# %%
import os.path
from jupyter_core.paths import jupyter_path

def find_extension(ext_path):
    for base in jupyter_path():
        curr_path = os.path.join(base, 'nbextensions', ext_path)
        if os.path.exists(curr_path):
            print('found extension at {!r}'.format(curr_path))

# %%
find_extension('config/main.js')

# %%
print(jupyter_path())
# Out:
# ['/home/skylark/.local/share/jupyter', '/home/skylark/anaconda2/envs/py3/share/jupyter', '/usr/local/share/jupyter', '/usr/share/jupyter']
